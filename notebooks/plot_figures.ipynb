# %%
from matplotlib import pyplot as plt
import numpy as np

agg = (0.705, 0.809, 0.768)
kmeans = (0.530, 0.890, 0.834)
gaussian_mixture = np.array([0.827])

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, agg, bar_width, alpha=opacity, color='b', label= 'Agglomerative')

rects2 = plt.bar(index + bar_width, kmeans, bar_width,
alpha=opacity,
color='g',
label='Kmeans')


rects3 = plt.bar(9*bar_width,gaussian_mixture , bar_width,
alpha=opacity,
color='r',
label='Gaussian mixture')

plt.xlabel('Affinity')
plt.ylabel('Rand score')
plt.title('Rand score by affinity')
plt.xticks(index + bar_width/2, ('p_norm', 'Euclidean', 'Cosine'))
plt.legend()

plt.tight_layout()
plt.savefig('./figures/3D_without_anchor.jpg')

# %%
from matplotlib import pyplot as plt
import numpy as np

agg = (0.606, 0.834, 0.818)
kmeans = (0.571, 0.902, 0.8825)
gaussian_mixture = np.array([0.819])

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, agg, bar_width, alpha=opacity, color='b', label= 'Agglomerative')

rects2 = plt.bar(index + bar_width, kmeans, bar_width,
alpha=opacity,
color='g',
label='Kmeans')


rects3 = plt.bar(9*bar_width,gaussian_mixture , bar_width,
alpha=opacity,
color='r',
label='Gaussian mixture')

plt.xlabel('Affinity')
plt.ylabel('Rand score')
plt.title('Rand score by affinity')
plt.xticks(index + bar_width/2, ('p_norm', 'Euclidean', 'Cosine'))
plt.legend()

plt.tight_layout()
plt.savefig('./figures/3D_with_anchor.jpg')

# %%
from matplotlib import pyplot as plt
import numpy as np

n_groups = 4
without_anchor = [0.890, 0.922, 0.861, 0.916]
with_anchor = [0.902, 0.915 , 0.924, 0.937]

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, without_anchor, bar_width, alpha=opacity, color='b', label= 'Without anchor')

rects2 = plt.bar(index + bar_width, with_anchor , bar_width,
alpha=opacity,
color='g',
label='With anchor')


plt.xlabel('Encoding')
plt.ylabel('Rand score')
plt.title('Rand score by encoding')
plt.xticks(index + bar_width/2, ('3D', 'Sturcture 1', 'Structure 2', 'Structure 3'))
plt.legend(loc = 'best')

plt.tight_layout()
plt.savefig('./figures/encoding_comparison.jpg')
