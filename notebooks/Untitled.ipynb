# %%
import sys
sys.path.append('..')
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
from utils.data import fetch_data, generate_data, int_to_label
from utils.distances import p_norm_distance, cos_distance, pairwise_distance
from utils.clustering import agg_clustering, kmeans
from utils.plotting import plot
from utils.encoding import power, make_good_unitary, encode_point, encode_dataset
from utils.hrr import random_vectors
import numpy as np

# %%
n_init = 10
max_iter = 300
tol = 0.0001
p = -3
init_centroids = 'random'
n_clusters = 4
affinity = 'p_norm'
affinity = 'euclidean'

# %%
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
labels, centers = kmeans(X, n_clusters, affinity)
plt.scatter(X[:,0], X[:,1], c = labels)
plt.scatter(centers[:,0],centers[:,1], c = 'red')
