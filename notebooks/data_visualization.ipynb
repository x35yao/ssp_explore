# %%
import numpy as np
# %matplotlib notebook
import sys
sys.path.append('..')

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
from utils.data import fetch_data, fetch_data_with_label, generate_data, label_to_int, divide_data
from utils.plotting import plot

# %%
# logfile_path = ['../data/raw/1599166289/data.pickle', '../data/raw/1599153598/data.pickle', '../data/raw/test/data.pickle']
logfile_path = ['../../roboSim/data/bin_picking/1632768702/data.pickle']

# %%
# data only for bolt
label_seq =  ['Bolt on table', 'Bolt in jig', 'Bolt assembled']
_,_,x, y = fetch_data_with_label(logfile_path)
y_int = label_to_int(y, label_seq)
# Out:
# (0,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-5f90141d2197> in <module>()
#       1 # data only for bolt
#       2 label_seq =  ['Bolt on table', 'Bolt in jig', 'Bolt assembled']
# ----> 3 _,_,x, y = fetch_data_with_label(logfile_path)
#       4 y_int = label_to_int(y, label_seq)
#
# ~/Desktop/project/ssp_explore/utils/data.py in fetch_data_with_label(x, n_states)
#     101     data_bolt = np.array(test_bolt)
#     102     print(data_nut.shape)
# --> 103     x_nut = data_nut[:,:3].astype(np.float)
#     104     y_nut = data_nut[:,3]
#     105     x_bolt = data_bolt[:,:3].astype(np.float)
#
# IndexError: too many indices for array

# %%
'''processed data have been saved'''
# np.save('../data/processed/x_processed.npy', x)
# np.save('../data/processed/y_processed.npy', y)

# label_seq =  ['Bolt on table', 'Bolt in jig', 'Bolt assembled']
# x = np.load('../data/processed/x_processed.npy')
# y = np.load('../data/processed/y_processed.npy')
# y_int = label_to_int(y, label_seq)
# Out:
# 'processed data have been saved'

# %%
fig = plt.figure(1, (12,4))
ax = fig.add_subplot(1, 2, 1, projection='3d')
plot(ax, x, y)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# # Divide data

# %%
x_train, y_train, x_test, y_test = divide_data(x, y_int, n_samples = 5)

# %%
x_train.shape
# Out:
# (15, 3)

# %% [markdown]
# # Training data

# %%
fig = plt.figure(2, (12,4))
ax = fig.add_subplot(1, 2, 1, projection='3d')
plot(ax, x_train, y_train)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# # Test data

# %%
fig = plt.figure(3, (12,4))
ax = fig.add_subplot(1, 2, 1, projection='3d')
plot(ax, x_test, y_test)
# Out:
# <img src="data:image/png;base64,..." width="1200">
